# %%
import random as r
plot(range(100), [r.randint(0,10) for i in range(100) ])

# %%
from PIL import Image
import pylab
dino = Image.open("412.jpg")
pylab.imshow(dino)

# %%
land = Image.open("826.jpg")
pylab.imshow(land)
pylab.show()
hist = land.histogram()
pylab.hist(hist,bins=40)
# Out:
# (array([59, 31, 66, 36, 36, 45, 28, 32, 18,  8, 18, 19, 16, 16, 22, 17, 22,
#        15, 13,  8, 15, 24, 18, 22, 25, 17, 16, 17, 18,  7, 10,  6, 16,  8,
#         9,  4,  5,  3,  1,  2]),
#  array([    0.   ,    28.375,    56.75 ,    85.125,   113.5  ,   141.875,
#          170.25 ,   198.625,   227.   ,   255.375,   283.75 ,   312.125,
#          340.5  ,   368.875,   397.25 ,   425.625,   454.   ,   482.375,
#          510.75 ,   539.125,   567.5  ,   595.875,   624.25 ,   652.625,
#          681.   ,   709.375,   737.75 ,   766.125,   794.5  ,   822.875,
#          851.25 ,   879.625,   908.   ,   936.375,   964.75 ,   993.125,
#         1021.5  ,  1049.875,  1078.25 ,  1106.625,  1135.   ]),
#  <a list of 40 Patch objects>)

# %%
from PIL import ImageFilter
im1 = dino.filter(ImageFilter.BLUR)
pylab.imshow(im1)

# %%
im2 = dino.filter(ImageFilter.FIND_EDGES)
pylab.imshow(im2)

# %%
im3 = land.filter(ImageFilter.EDGE_ENHANCE_MORE)
pylab.imshow(im3)

# %%
im4 = land.filter(ImageFilter.CONTOUR)
pylab.imshow(im4)

# %%
from PIL import ImageOps
im5 = ImageOps.invert(dino)
pylab.imshow(im5)

# %%
im6 = ImageOps.grayscale(dino)
pylab.imshow(im6)

# %%
im7 = ImageOps.solarize(dino, threshold=128)
pylab.imshow(im7)

# %%
im8 = land.transpose(Image.ROTATE_270)
pylab.imshow(im8)

# %%
im8 = land.transpose(Image.FLIP_TOP_BOTTOM)
pylab.imshow(im8)

# %%
im9 = land.crop((20, 20, 200, 100))
pylab.imshow(im9)
